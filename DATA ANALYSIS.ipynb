# %%
import matplotlib.pyplot as plt
import numpy as np
import utils.utils

# %% [markdown]
# # Delta Data

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

regional_downtick = [("NCR", 76.5, 0.000000000000884, 39.7), ("CAR", 55.9, 0, 40.9), ("I", 57.0, 0, 45.6), ("II", 54.8, 0, 30.0),  
                    ("III", 54.5, 3.6, 12.3), ("IV-A", 52.0, 0, 43.3), ("IV-B", 44.3, 0.00000000000178, 25.0), ("V", 44.5, 0, 45),  
                    ("VI", 51.3, 11.1, 18.6), ("VII", 40.5, 25.0, 41.7), ("VIII", 44.6, 12.5, 76.1), ("IX", 44.7, 0, 12),  
                    ("X", 49.0, 0, 29.2), ("XI", 50.0, 50, 64.1), ("XII", 39.6, 0, 55.8), ("XIII", 43.7, 100, 41.7),
                    ("BARMM", 17.7, 0, 3.8)]

# https://en.wikipedia.org/wiki/Regions_of_the_Philippines

ax.bar([x[0] for x in regional_downtick], [x[1] for x in regional_downtick], color="#7aff9e", width=0.5)
ax.bar([x[0] for x in regional_downtick], [1], color="r", bottom=[x[2] for x in regional_downtick], width=0.5)
ax.bar([x[0] for x in regional_downtick], [1], color="b", bottom=[x[3] for x in regional_downtick], width=0.5)
plt.xticks(range(0, len(regional_downtick)), [x[0] for x in regional_downtick], size="small")

plt.legend(["Current vaccination coverage", "Infection downtick", "Death downtick"])
plt.xlabel("Regions")
plt.ylabel("Percentage (%)")
plt.show()

# %% [markdown]
# ### Updated

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

regional_downtick = [("NCR", 76.5, 0, 39.7), ("CAR", 55.9, 0, 41), ("I", 57.0, 0, 55.9), ("II", 54.8, 0, 30.0),  
                    ("III", 54.5, 3.6, 12.3), ("IV-A", 52.0, 0, 43.3), ("IV-B", 44.3, 0, 25.0), ("V", 44.5, 0, 45),  
                    ("VI", 51.3, 11.1, 18.6), ("VII", 40.5, 25.0, 34.2), ("VIII", 44.6, 12.5, 76.1), ("IX", 44.7, 0, 12),  
                    ("X", 49.0, 0, 29.2), ("XI", 50.0, 50, 64.1), ("XII", 39.6, 0, 51.2), ("XIII", 43.7, 100, 41.7),
                    ("BARMM", 17.7, 0, 3.9)]

# https://en.wikipedia.org/wiki/Regions_of_the_Philippines

ax.bar([x[0] for x in regional_downtick], [x[1] for x in regional_downtick], color="#7aff9e", width=0.5)
ax.bar([x[0] for x in regional_downtick], [1], color="r", bottom=[x[2] for x in regional_downtick], width=0.5)
ax.bar([x[0] for x in regional_downtick], [1], color="b", bottom=[x[3] for x in regional_downtick], width=0.5)
plt.xticks(range(0, len(regional_downtick)), [x[0] for x in regional_downtick], size="small")

plt.legend(["Vaccination coverage as of Feb 13", "Infection downtick", "Death downtick"])
plt.xlabel("Regions")
plt.ylabel("Percentage (%)")
plt.show()

# %% [markdown]
# # Omicron Data

# %% [markdown]
# ### Vaccination data as of Feb 13

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

regional_downtick = [("NCR", 76.5, 0, 17.4), ("CAR", 55.9, 0, 23.61), ("I", 57.0, 45, 8.33), ("II", 54.8, 0, 14.58),  
                    ("III", 54.5, 42.86, 43.41), ("IV-A", 52.0, 0, 26.22), ("IV-B", 44.3, 0, 20.59), ("V", 44.5, 0, 45),  
                    ("VI", 51.3, 0, 12.14), ("VII", 40.5, 0, 58), ("VIII", 44.6, 0, 16.07), ("IX", 44.7, 0, 53.57),  
                    ("X", 49.0, 0, 55.83), ("XI", 50.0, 0, 50.81), ("XII", 39.6, 0, 0), ("XIII", 43.7, 56.25, 29.41),
                    ("BARMM", 17.7, 0, 31.67)]

# https://en.wikipedia.org/wiki/Regions_of_the_Philippines

ax.bar([x[0] for x in regional_downtick], [x[1] for x in regional_downtick], color="#7aff9e", width=0.5)
ax.bar([x[0] for x in regional_downtick], [1], color="r", bottom=[x[2] for x in regional_downtick], width=0.5)
ax.bar([x[0] for x in regional_downtick], [1], color="b", bottom=[x[3] for x in regional_downtick], width=0.5)
plt.xticks(range(0, len(regional_downtick)), [x[0] for x in regional_downtick], size="small")

plt.legend(["Vaccination coverage as of Feb 13", "Infection downtick", "Death downtick"])
plt.xlabel("Regions")
plt.ylabel("Percentage (%)")
plt.show()

# %% [markdown]
# ### Vaccination data as of Apr 19

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

regional_downtick = [("NCR", 85.5, 0, 17.4), ("CAR", 62.8, 0, 23.61), ("I", 65.7, 45, 8.33), ("II", 64, 0, 14.58),  
                    ("III", 63.8, 42.86, 43.41), ("IV-A", 60.7, 0, 26.22), ("IV-B", 52.4, 0, 20.59), ("V", 52.9, 0, 45),  
                    ("VI", 75.3, 0, 12.14), ("VII", 60.7, 0, 58), ("VIII", 53.9, 0, 16.07), ("IX", 60.7, 0, 53.57),  
                    ("X", 56.7, 0, 55.83), ("XI", 56.1, 0, 50.81), ("XII", 47.4, 0, 0), ("XIII", 55.32, 56.25, 29.41),
                    ("BARMM", 22.1, 0, 31.67)]

# https://en.wikipedia.org/wiki/Regions_of_the_Philippines

ax.bar([x[0] for x in regional_downtick], [x[1] for x in regional_downtick], color="#7aff9e", width=0.5)
ax.bar([x[0] for x in regional_downtick], [1], color="r", bottom=[x[2] for x in regional_downtick], width=0.5)
ax.bar([x[0] for x in regional_downtick], [1], color="b", bottom=[x[3] for x in regional_downtick], width=0.5)
plt.xticks(range(0, len(regional_downtick)), [x[0] for x in regional_downtick], size="small")

plt.legend(["Vaccine coverage as of Apr 19", "Infection downtick", "Death downtick"])
plt.xlabel("Regions")
plt.ylabel("Percentage (%)")
plt.show()
